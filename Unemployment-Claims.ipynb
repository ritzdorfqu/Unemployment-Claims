# %%
import pandas as pd

# %%
national_claims = pd.read_csv('https://query.data.world/s/dyycbtim2ehbfsdf4fdli2tu3byie2')

# %%
national_claims.head()
# Out:
#          date  claims  claims_sa  claims_ma  insured_newly_unemployed_rate  \
# 0  2000-01-01  439912     286000     278250                           0.36
# 1  2000-01-08  606897     298000     284750                           0.49
# 2  2000-01-15  442494     289000     285250                           0.36
# 3  2000-01-22  328841     284000     289250                           0.27
# 4  2000-01-29  332740     285000     289000                           0.27
#
#    covered_employment  pct_lastweek  pct_lastyear  pct_lastweek_sa  \
# 0           123830071          16.5         -13.6              6.7
# 1           123830071          38.0         -15.0              4.2
# 2           123830071         -27.1         -13.9             -3.0
# 3           123830071         -25.7          -9.8             -1.7
# 4           123830071           1.2          -4.9              0.4
#
#    pct_lastyear_sa  ...  cont_claims_sa  cont_claims_ma  \
# ...

# %%
state_claims = pd.read_csv('https://query.data.world/s/nqhhiw2bajd5qmf6elkq3dm3dnge43')

# %%
state_claims.head()
# Out:
#         state        date  claims  claims_ma  insured_newly_unemployed_rate  \
# 0     Alabama  2000-01-01   10099    6102.50                           0.56
# 1      Alaska  2000-01-01    1757    1928.50                           0.70
# 2    Arkansas  2000-01-01    7181    5161.25                           0.67
# 3     Arizona  2000-01-01    2237    2666.25                           0.11
# 4  California  2000-01-01   37401   46086.00                           0.27
#
#    covered_employment  pct_lastweek  pct_lastyear  pct_lastweek_ma  \
# 0             1806088         178.4           2.0              7.5
# 1              250936          -3.5         -21.4             -4.4
# 2             1072034          27.8         -24.2              4.6
# 3             2046519           0.0          45.8             -5.8
# 4            13844545         -23.4         -20.9            -11.0
#
#    pct_lastyear_ma  cont_claims  cont_claims_ma  insured_unemployed_rate  \
# ...

# %%
missouri_claims = pd.read_csv('https://download.data.world/s/xjccdccxnkpwxlzyjru77kknt747lr')

# %%
missouri_claims.head()
# Out:
#       state        date  claims  claims_ma  insured_newly_unemployed_rate  \
# 0  Missouri  2000-01-01   10649    9507.25                           0.42
# 1  Missouri  2000-01-08   13511   11146.75                           0.53
# 2  Missouri  2000-01-15    9234   11213.25                           0.36
# 3  Missouri  2000-01-22    6248    9910.50                           0.24
# 4  Missouri  2000-01-29    8162    9288.75                           0.32
#
#    covered_employment  pct_lastweek  pct_lastyear  pct_lastweek_ma  \
# 0             2558583          -7.1         -20.1              9.0
# 1             2567623          26.9         -17.5             17.2
# 2             2567623         -31.7         -33.1              0.6
# 3             2567623         -32.3         -10.8            -11.6
# 4             2567623          30.6          29.8             -6.3
#
#    pct_lastyear_ma  cont_claims  cont_claims_ma  insured_unemployed_rate  \
# ...

# %%
state_funds = pd.read_csv('https://query.data.world/s/vbjpqttbhplufeb35bt4oedqfur74p')

# %%
state_funds.head()
# Out:
#         state  fund_balance  reserve_ratio  solvency_level  \
# 0      Alaska     500977665           3.79            1.68
# 1     Alabama     704456280           0.92            1.00
# 2    Arkansas     846046865           1.94            1.31
# 3     Arizona    1097519502           0.87            0.92
# 4  California    3260789629           0.32            0.21
#
#    last_year_hcm_achieved
# 0                    2019
# 1                    2019
# 2                    2019
# 3                    2008
# 4                    1990

# %% [markdown]
# ## State with the most claims since 2000?
#
# Missouri is 15th

# %%
state_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56127 entries, 0 to 56126
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          56127 non-null  object
#  1   date                           56127 non-null  object
#  2   claims                         56127 non-null  int64
#  3   claims_ma                      56127 non-null  float64
#  4   insured_newly_unemployed_rate  56127 non-null  float64
#  5   covered_employment             56127 non-null  int64
#  6   pct_lastweek                   56127 non-null  float64
#  7   pct_lastyear                   56074 non-null  float64
#  8   pct_lastweek_ma                56127 non-null  float64
#  9   pct_lastyear_ma                55915 non-null  float64
#  10  cont_claims                    56074 non-null  float64
#  11  cont_claims_ma                 56074 non-null  float64
# ...

# %%
state_claims.claims_ma.sum()
# Out:
# 375409400.0

# %%
state_claims.groupby('state').claims.sum().reset_index().sort_values('claims', ascending=False)
# Out:
#                    state    claims
# 4             California  57872216
# 38          Pennsylvania  24607997
# 32              New York  23942306
# 44                 Texas  18835989
# 22              Michigan  16853352
# 13              Illinois  15364013
# 35                  Ohio  13739584
# 9                Florida  13281278
# 33        North Carolina  13079215
# 51             Wisconsin  12372686
# 30            New Jersey  12244406
# 10               Georgia  11626472
# 49            Washington  10619756
# 21         Massachusetts   8676314
# 25              Missouri   7896102
# 37                Oregon   7633707
# 14               Indiana   7500938
# 43             Tennessee   6947674
# 48              Virginia   6296335
# 23             Minnesota   6090073
# 41        South Carolina   6077074
# 17              Kentucky   6028773
# 0                Alabama   5665036
# 20              Maryland   5395521
# 2                Arizona   5324272
# 6            Connecticut   4816938
# ...

# %% [markdown]
# ## State with the most claims on the week ending 2020-04-04?
#
# California. Missouri is 25th.

# %%
state_claims[
    state_claims['date'] == '2020-04-04'
].sort_values(
    'claims', ascending=False
)
# Out:
#                       state        date  claims  claims_ma  \
# 56025            California  2020-04-04  918814  555269.50
# 56031               Georgia  2020-04-04  390132  135384.25
# 56043              Michigan  2020-04-04  388554  206558.25
# 56055              New York  2020-04-04  344451  201329.25
# 56065                 Texas  2020-04-04  315167  190738.50
# 56059          Pennsylvania  2020-04-04  277640  268801.75
# 56056                  Ohio  2020-04-04  226191  175958.50
# 56052            New Jersey  2020-04-04  214836  136592.75
# 56034              Illinois  2020-04-04  201041  126111.50
# 56070            Washington  2020-04-04  171252  124562.50
# 56030               Florida  2020-04-04  169885  119786.25
# 56069              Virginia  2020-04-04  147369   77212.25
# 56042         Massachusetts  2020-04-04  139647  119242.75
# 56048        North Carolina  2020-04-04  137422  101795.75
# 56024               Arizona  2020-04-04  132428   63640.00
# ...

# %% [markdown]
# ## What week since 2000 has the most claims? Graph it
#
# 1-3 are all the weeks involving the virus

# %%
state_claims.groupby('date').claims.sum().reset_index().sort_values('claims', ascending=False)
# Out:
#             date   claims
# 1057  2020-04-04  6211406
# 1056  2020-03-28  6015821
# 1058  2020-04-11  4971823
# 1055  2020-03-21  2920162
# 471   2009-01-10   956791
# ...          ...      ...
# 977   2018-09-22   172930
# 978   2018-09-29   171816
# 1024  2019-08-17   171386
# 975   2018-09-08   162640
# 1027  2019-09-07   160342
#
# [1059 rows x 2 columns]

# %% [markdown]
# ## What percentage of the workforce do the 2020-04-04 claims represent nationally?
#
# 4.28%

# %%
national_claims[
    national_claims['date'] == '2020-04-04'
]
# Out:
#             date   claims  claims_sa  claims_ma  \
# 1057  2020-04-04  6211399    6615000    4267750
#
#       insured_newly_unemployed_rate  covered_employment  pct_lastweek  \
# 1057                           4.28           145230691           3.3
#
#       pct_lastyear  pct_lastweek_sa  pct_lastyear_sa  ...  cont_claims_sa  \
# 1057        3067.9             -3.7           3158.6  ...      11976000.0
#
#       cont_claims_ma  insured_unemployed_rate  insured_unemployed_rate_sa  \
# 1057       6066250.0                     8.63                        8.25
#
#       cont_claims_pct_lastweek  cont_claims_pct_lastyear  \
# 1057                      53.4                     624.0
#
#       cont_claims_pct_lastweek_sa  cont_claims_pct_lastyear_sa  \
# 1057                         60.8                        618.4
#
#       cont_claims_pct_lastweek_ma  cont_claims_pct_lastyear_ma
# 1057                         73.4                        255.6
#
# [1 rows x 23 columns]

# %% [markdown]
# ## What is the national percentage change of new claims per week since the virus started? Graph it

# %%
virus_date = '2020-03-07'

# %%
national_claims[
    national_claims['date'] >= virus_date
].groupby('date').pct_lastweek.sum().reset_index()
# Out:
#          date  pct_lastweek
# 0  2020-03-07          -7.5
# 1  2020-03-14          25.5
# 2  2020-03-21        1061.5
# 3  2020-03-28         106.0
# 4  2020-04-04           3.3
# 5  2020-04-11         -20.0

# %% [markdown]
# ## What is the national percentage change from last year for the weeks of the virus? Graph it

# %%
national_claims[
    national_claims['date'] >= virus_date
].groupby('date').pct_lastyear.sum().reset_index()
# Out:
#          date  pct_lastyear
# 0  2020-03-07          -4.3
# 1  2020-03-14          29.4
# 2  2020-03-21        1436.7
# 3  2020-03-28        3173.5
# 4  2020-04-04        3067.9
# 5  2020-04-11        2431.9

# %% [markdown]
# ## What is the national total number of people on claims?
#
# 8,177,965 people. 2020-04-04 isn't updated yet and has just 0.0

# %%
national_claims[
    national_claims['date'] == '2020-03-28'
].groupby('date').cont_claims.sum().reset_index()
# Out:
#          date  cont_claims
# 0  2020-03-28    8168271.0

# %% [markdown]
# ## Is that the most since 2000?
#
# Yes by more than 1.5 million claims

# %%
national_claims.groupby('date').cont_claims.sum().reset_index().sort_values('cont_claims', ascending=False)
# Out:
#             date  cont_claims
# 1057  2020-04-04   12526711.0
# 1056  2020-03-28    8168271.0
# 482   2009-03-28    6451690.0
# 480   2009-03-14    6440135.0
# 484   2009-04-11    6406046.0
# ...          ...          ...
# 980   2018-10-13    1370783.0
# 1031  2019-10-05    1369887.0
# 978   2018-09-29    1369317.0
# 979   2018-10-06    1350834.0
# 1058  2020-04-11          0.0
#
# [1059 rows x 2 columns]

# %% [markdown]
# ## What is the national percentage change of total claims per week since the virus started?

# %%
national_claims[
    national_claims['date'] >= virus_date
].groupby('date').cont_claims_pct_lastweek.sum().reset_index()
# Out:
#          date  cont_claims_pct_lastweek
# 0  2020-03-07                      -3.9
# 1  2020-03-14                       4.9
# 2  2020-03-21                      64.7
# 3  2020-03-28                     139.1
# 4  2020-04-04                      53.4
# 5  2020-04-11                       0.0

# %% [markdown]
# ## What is the national percentage change of total claims from last year per week since the virus started?

# %%
national_claims[
    national_claims['date'] >= virus_date
].groupby('date').cont_claims_pct_lastyear.sum().reset_index()
# Out:
#          date  cont_claims_pct_lastyear
# 0  2020-03-07                      -1.5
# 1  2020-03-14                       3.3
# 2  2020-03-21                      79.0
# 3  2020-03-28                     338.8
# 4  2020-04-04                     624.0
# 5  2020-04-11                       0.0

# %% [markdown]
# ## What state has the most claims per week since the virus started?
#
# California during the week of Mar. 28 and Apr. 4.

# %%
state_claims[
    state_claims['date'] >= virus_date
].sort_values(
    'claims', ascending=False
)
# Out:
#                 state        date   claims  claims_ma  \
# 55972      California  2020-03-28  1058325  336412.25
# 56025      California  2020-04-04   918814  555269.50
# 56078      California  2020-04-11   660966  706109.50
# 56006    Pennsylvania  2020-03-28   404677  202448.50
# 56106        New York  2020-04-11   395949  296748.50
# ...               ...         ...      ...        ...
# 55962  Virgin Islands  2020-03-21      123      67.00
# 56068  Virgin Islands  2020-04-04       72     122.25
# 55856  Virgin Islands  2020-03-07       64      49.00
# 55909  Virgin Islands  2020-03-14       44      50.00
# 56121  Virgin Islands  2020-04-11        3     112.00
#
#        insured_newly_unemployed_rate  covered_employment  pct_lastweek  \
# 55972                           6.13            17265039         468.0
# 56025                           5.32            17265039         -13.2
# 56078                           3.83            17265039         -28.1
# ...

# %% [markdown]
# ## Rank of states based on total number of people covered by claims?
#
# Missouri ranks 20th with 2.7 million people that are covered by UI.

# %%
state_claims[
    state_claims['date'] == '2020-04-11'
].sort_values(
    'covered_employment', ascending=False
)
# Out:
#                       state        date  claims  claims_ma  \
# 56078            California  2020-04-11  660966  706109.50
# 56118                 Texas  2020-04-11  273567  255086.25
# 56106              New York  2020-04-11  395949  296748.50
# 56083               Florida  2020-04-11  181293  163493.75
# 56087              Illinois  2020-04-11  141049  158656.25
# 56112          Pennsylvania  2020-04-11  238357  324531.25
# 56109                  Ohio  2020-04-11  157218  213501.50
# 56107        North Carolina  2020-04-11  137934  135396.00
# 56084               Georgia  2020-04-11  317526  213404.50
# 56096              Michigan  2020-04-11  219320  260053.75
# 56104            New Jersey  2020-04-11  140600  169376.00
# 56122              Virginia  2020-04-11  106723  103216.50
# 56095         Massachusetts  2020-04-11  103040  143140.50
# 56123            Washington  2020-04-11  150516  158631.50
# 56117             Tennessee  2020-04-11   74772   79383.75
# ...

# %% [markdown]
# ## Which state has the greatest weekly percentage change since virus started?
#
# New Hampshire from Mar. 14-21.

# %%
state_claims[
    state_claims['date'] >= virus_date
].sort_values(
    'pct_lastweek', ascending=False
)
# Out:
#                 state        date  claims  claims_ma  \
# 55945   New Hampshire  2020-03-21   29379    7852.50
# 55934           Maine  2020-03-21   21459    5917.50
# 55955    Rhode Island  2020-03-21   35847    9632.25
# 55933       Louisiana  2020-03-21   72438   19475.00
# 55938       Minnesota  2020-03-21  115773   31670.25
# ...               ...         ...     ...        ...
# 55855         Vermont  2020-03-07     446     615.50
# 55843        New York  2020-03-07   14035   18430.00
# 56093           Maine  2020-04-11   13273   22353.00
# 56068  Virgin Islands  2020-04-04      72     122.25
# 56121  Virgin Islands  2020-04-11       3     112.00
#
#        insured_newly_unemployed_rate  covered_employment  pct_lastweek  \
# 55945                           4.49              654468        4476.2
# 55934                           3.56              602736        3284.7
# 55955                           7.58              472874        3135.3
# ...

# %% [markdown]
# ## Which state has the greatest yearly percentage change per week since virus started?
#
# Georgia on the week of Apr. 4.

# %%
state_claims[
    state_claims['date'] >= virus_date
].sort_values(
    'pct_lastyear', ascending=False
)
# Out:
#                 state        date  claims  claims_ma  \
# 56031         Georgia  2020-04-04  390132  135384.25
# 56051   New Hampshire  2020-04-04   39202   25150.25
# 56116    South Dakota  2020-04-11    6152    5713.00
# 55998   New Hampshire  2020-03-28   31378   15473.50
# 55982         Indiana  2020-03-28  139174   50937.00
# ...               ...         ...     ...        ...
# 55822        Illinois  2020-03-07    8727    9391.00
# 55838        Nebraska  2020-03-07     501     508.25
# 55898        Oklahoma  2020-03-14    1836    1593.00
# 55846          Oregon  2020-03-07    4154    3972.00
# 56121  Virgin Islands  2020-04-11       3     112.00
#
#        insured_newly_unemployed_rate  covered_employment  pct_lastweek  \
# 56031                           8.92             4373059         191.5
# 56051                           5.99              654468          24.9
# 56116                           1.48              417030         -24.4
# ...

# %% [markdown]
# ## Which state has the most people on UI?
#
# Missouri is 19th with 121,467 people on UI.

# %%
state_claims[
    state_claims['date'] == '2020-04-04'
].groupby('state').cont_claims.sum().reset_index().sort_values('cont_claims', ascending=False)
# Out:
#                    state  cont_claims
# 4             California    1076761.0
# 32              New York     712544.0
# 38          Pennsylvania     566464.0
# 35                  Ohio     450061.0
# 44                 Texas     374656.0
# 22              Michigan     366426.0
# 10               Georgia     360077.0
# 21         Massachusetts     310211.0
# 49            Washington     309411.0
# 30            New Jersey     276119.0
# 13              Illinois     263057.0
# 23             Minnesota     248023.0
# 33        North Carolina     245692.0
# 51             Wisconsin     208387.0
# 6            Connecticut     147939.0
# 48              Virginia     133184.0
# 28                Nevada     131121.0
# 17              Kentucky     130151.0
# 25              Missouri     121467.0
# 37                Oregon     118729.0
# 18             Louisiana     116690.0
# 43             Tennessee     116179.0
# 9                Florida      98921.0
# 20              Maryland      92112.0
# ...

# %% [markdown]
# ## States percentage change of total claims per week since the virus started?

# %%
state_claims[
    state_claims['date'] >= virus_date
].sort_values(
    'cont_claims_pct_lastweek', ascending=False
)
# Out:
#                state        date  claims  claims_ma  \
# 55998  New Hampshire  2020-03-28   31378   15473.50
# 56038       Kentucky  2020-04-04  117575   70633.00
# 56059   Pennsylvania  2020-04-04  277640  268801.75
# 56043       Michigan  2020-04-04  388554  206558.25
# 55986      Louisiana  2020-03-28   97400   43447.75
# ...              ...         ...     ...        ...
# 56122       Virginia  2020-04-11  106723  103216.50
# 56123     Washington  2020-04-11  150516  158631.50
# 56124  West Virginia  2020-04-11   14595   11787.00
# 56125      Wisconsin  2020-04-11   69884   84168.00
# 56126        Wyoming  2020-04-11    4904    5374.00
#
#        insured_newly_unemployed_rate  covered_employment  pct_lastweek  \
# 55998                           4.79              654468           6.8
# 56038                           6.22             1890475           3.9
# 56059                           4.79             5800562         -31.4
# ...

# %% [markdown]
# ## States percentage change of total claims from last year per week since the virus started?

# %%
state_claims[
    state_claims['date'] >= virus_date
].sort_values(
    'cont_claims_pct_lastyear', ascending=False
)
# Out:
#                 state        date  claims  claims_ma  \
# 56031         Georgia  2020-04-04  390132  135384.25
# 56051   New Hampshire  2020-04-04   39202   25150.25
# 56048  North Carolina  2020-04-04  137422  101795.75
# 56039       Louisiana  2020-04-04  100621   68178.50
# 56050        Nebraska  2020-04-04   27054   17068.50
# ...               ...         ...     ...        ...
# 56122        Virginia  2020-04-11  106723  103216.50
# 56123      Washington  2020-04-11  150516  158631.50
# 56124   West Virginia  2020-04-11   14595   11787.00
# 56125       Wisconsin  2020-04-11   69884   84168.00
# 56126         Wyoming  2020-04-11    4904    5374.00
#
#        insured_newly_unemployed_rate  covered_employment  pct_lastweek  \
# 56031                           8.92             4373059         191.5
# 56051                           5.99              654468          24.9
# 56048                           3.14             4381417         -20.2
# ...

# %% [markdown]
# ## What state has the most money in the UI fund?
#
# Missouri is 26th with $1.07 billion.

# %%
state_funds.groupby('state').fund_balance.sum().reset_index().sort_values('fund_balance', ascending=False)
# Out:
#                    state  fund_balance
# 36                Oregon    5054857898
# 48            Washington    4778075957
# 21              Michigan    4661100963
# 9                Florida    4071519600
# 32        North Carolina    4003197955
# 37          Pennsylvania    3435423679
# 4             California    3260789629
# 29            New Jersey    2888365115
# 31              New York    2651482639
# 10               Georgia    2559981541
# 50             Wisconsin    1971405287
# 13              Illinois    1946242074
# 27                Nevada    1940100622
# 43                 Texas    1934397487
# 22             Minnesota    1705263924
# 47              Virginia    1464142254
# 42             Tennessee    1273986041
# 20              Maryland    1273594518
# 34                  Ohio    1264072100
# 15                  Iowa    1260136829
# 44                  Utah    1172615481
# 5               Colorado    1153504105
# 35              Oklahoma    1116304233
# ...

# %% [markdown]
# ## How much money does Missouri have in the UI fund?

# %%
state_funds[
    state_funds['state'] == 'Missouri'
].groupby('state').fund_balance.sum().reset_index()
# Out:
#       state  fund_balance
# 0  Missouri    1070141101

# %% [markdown]
# ## Missouri's reserve ratio?
#
# Missouri is 37th with .98.

# %%
state_funds.groupby('state').reserve_ratio.sum().reset_index().sort_values('reserve_ratio', ascending=False)
# Out:
#                    state  reserve_ratio
# 36                Oregon           6.00
# 45               Vermont           5.00
# 38           Puerto Rico           3.87
# 1                 Alaska           3.79
# 51               Wyoming           3.62
# 27                Nevada           3.14
# 12                 Idaho           2.80
# 39          Rhode Island           2.76
# 48            Washington           2.56
# 11                Hawaii           2.53
# 19                 Maine           2.50
# 21              Michigan           2.48
# 25               Montana           2.25
# 15                  Iowa           2.15
# 32        North Carolina           2.12
# 23           Mississippi           2.04
# 3               Arkansas           1.94
# 44                  Utah           1.90
# 50             Wisconsin           1.76
# 35              Oklahoma           1.68
# 16                Kansas           1.68
# 30            New Mexico           1.63
# ...

# %%
state_funds[
    state_funds['state'] == 'Missouri'
].groupby('state').reserve_ratio.sum().reset_index()
# Out:
#       state  reserve_ratio
# 0  Missouri           0.98

# %% [markdown]
# ## What week in Missouri has the most claims?
#
# Mar. 28 with 104,291.

# %%
missouri_claims.groupby('date').claims.sum().reset_index().sort_values('claims', ascending=False)
# Out:
#             date  claims
# 1056  2020-03-28  104291
# 1058  2020-04-11   95785
# 1057  2020-04-04   91458
# 1055  2020-03-21   42246
# 262   2005-01-08   21550
# ...          ...     ...
# 1008  2019-04-27    2397
# 978   2018-09-29    2382
# 1007  2019-04-20    2381
# 1027  2019-09-07    2116
# 880   2016-11-12    1865
#
# [1059 rows x 2 columns]

# %% [markdown]
# ## What percentage of the workforce do the 2020-04-04 claims represent in Missouri?
#
# 3.48%

# %%
missouri_claims[
    missouri_claims['date'] == '2020-04-11'
]
# Out:
#          state        date  claims  claims_ma  insured_newly_unemployed_rate  \
# 1058  Missouri  2020-04-11   95785    83445.0                           3.48
#
#       covered_employment  pct_lastweek  pct_lastyear  pct_lastweek_ma  \
# 1058             2749100           4.7        3291.8             37.9
#
#       pct_lastyear_ma  cont_claims  cont_claims_ma  insured_unemployed_rate  \
# 1058           2684.7          NaN             NaN                      NaN
#
#       cont_claims_pct_lastweek  cont_claims_pct_lastyear  \
# 1058                       NaN                       NaN
#
#       cont_claims_pct_lastweek_ma  cont_claims_pct_lastyear_ma
# 1058                          NaN                          NaN

# %% [markdown]
# ## Percentage of people in Missouri covered by the claims per week since the virus started?

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').insured_newly_unemployed_rate.sum().reset_index()
# Out:
#          date  insured_newly_unemployed_rate
# 0  2020-03-07                           0.11
# 1  2020-03-14                           0.15
# 2  2020-03-21                           1.54
# 3  2020-03-28                           3.79
# 4  2020-04-04                           3.33
# 5  2020-04-11                           3.48

# %% [markdown]
# ## Total number of people in Missouri covered by the employment?
#
# 2.7 million people.

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').covered_employment.sum().reset_index()
# Out:
#          date  covered_employment
# 0  2020-03-07             2749100
# 1  2020-03-14             2749100
# 2  2020-03-21             2749100
# 3  2020-03-28             2749100
# 4  2020-04-04             2749100
# 5  2020-04-11             2749100

# %% [markdown]
# ## Weekly percentage change of claims in Missouri since virus started?

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').pct_lastweek.sum().reset_index()
# Out:
#          date  pct_lastweek
# 0  2020-03-07           9.6
# 1  2020-03-14          34.1
# 2  2020-03-21         951.9
# 3  2020-03-28         146.9
# 4  2020-04-04         -12.3
# 5  2020-04-11           4.7

# %% [markdown]
# ## Yearly percentage change of claims per week in Missouri since virus started?

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').pct_lastyear.sum().reset_index()
# Out:
#          date  pct_lastyear
# 0  2020-03-07          -1.4
# 1  2020-03-14          24.2
# 2  2020-03-21        1087.7
# 3  2020-03-28        3416.2
# 4  2020-04-04        3365.6
# 5  2020-04-11        3291.8

# %% [markdown]
# ## How many people have filed unemployment claims in Missouri since virus started?

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].claims.sum()
# Out:
# 340790

# %% [markdown]
# ## Total number of people on UI in Missouri right now?
#
# 121,467.

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').cont_claims.sum().reset_index()
# Out:
#          date  cont_claims
# 0  2020-03-07      25225.0
# 1  2020-03-14      22381.0
# 2  2020-03-21      21538.0
# 3  2020-03-28      49470.0
# 4  2020-04-04     121467.0
# 5  2020-04-11          0.0

# %% [markdown]
# ## Missouri percentage change of total claims per week since the virus started?

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').cont_claims_pct_lastweek.sum().reset_index()
# Out:
#          date  cont_claims_pct_lastweek
# 0  2020-03-07                      -6.4
# 1  2020-03-14                     -11.3
# 2  2020-03-21                      -3.8
# 3  2020-03-28                     129.7
# 4  2020-04-04                     145.5
# 5  2020-04-11                       0.0

# %% [markdown]
# ## Missouri percentage change of total claims from last year per week since the virus started?

# %%
missouri_claims[
    missouri_claims['date'] >= virus_date
].groupby('date').cont_claims_pct_lastyear.sum().reset_index()
# Out:
#          date  cont_claims_pct_lastyear
# 0  2020-03-07                      -5.8
# 1  2020-03-14                     -13.2
# 2  2020-03-21                      -7.5
# 3  2020-03-28                     114.2
# 4  2020-04-04                     490.6
# 5  2020-04-11                       0.0
